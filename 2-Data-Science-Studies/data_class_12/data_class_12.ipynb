# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv("water_consumption.csv", delimiter="\t")
df.head()
# Out:
#    initial  final  price  month  year block  apartment
# 0     3535   3565  464.1      7  2023     A         11
# 1     3375   3402  380.1      7  2023     A         12
# 2     3620   3651  492.1      7  2023     A         21
# 3     4681   4707  352.1      7  2023     A         22
# 4     2400   2425  324.1      7  2023     A         31

# %% [markdown]
# ## 3. Creation of Consumption Column and Dummies

# %%
df["consumption"] = df["final"] - df["initial"]
df = df.drop(columns=["month", "year"])
df = pd.get_dummies(df, columns=["block"])
df.head()
# Out:
#    initial  final  price  apartment  consumption  block_A  block_B  block_C  \
# 0     3535   3565  464.1         11           30     True    False    False
# 1     3375   3402  380.1         12           27     True    False    False
# 2     3620   3651  492.1         21           31     True    False    False
# 3     4681   4707  352.1         22           26     True    False    False
# 4     2400   2425  324.1         31           25     True    False    False
#
#    block_D  block_E  block_F  block_G
# 0    False    False    False    False
# 1    False    False    False    False
# 2    False    False    False    False
# 3    False    False    False    False
# 4    False    False    False    False

# %% [markdown]
# ## 4. OLS Summary

# %%
y = df["consumption"]
x = df.drop(columns=["consumption"])

x = x.apply(pd.to_numeric, errors="coerce").astype(float)
x = sm.add_constant(x, has_constant="add")

model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            consumption   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.390e+28
# Date:                Sat, 23 Aug 2025   Prob (F-statistic):               0.00
# Time:                        20:30:29   Log-Likelihood:                 10562.
# No. Observations:                 390   AIC:                        -2.110e+04
# Df Residuals:                     379   BIC:                        -2.106e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.751e-13    7.2e-14     -7.982      0.000   -7.17e-13   -4.33e-13
# initial       -1.0000   4.75e-15  -2.11e+14      0.000      -1.000      -1.000
# final          1.0000   4.74e-15   2.11e+14      0.000       1.000       1.000
# price      -6.288e-18    2.2e-16     -0.029      0.977   -4.39e-16    4.27e-16
# apartment  -1.666e-15   3.42e-16     -4.868      0.000   -2.34e-15   -9.93e-16
# block_A    -2.183e-13   5.88e-14     -3.715      0.000   -3.34e-13   -1.03e-13
# block_B    -7.123e-14   5.98e-14     -1.190      0.235   -1.89e-13    4.64e-14
# block_C     -5.79e-14      6e-14     -0.965      0.335   -1.76e-13    6.01e-14
# block_D     -6.86e-14    4.6e-14     -1.490      0.137   -1.59e-13    2.19e-14
# block_E    -4.251e-14   4.62e-14     -0.920      0.358   -1.33e-13    4.84e-14
# block_F    -5.723e-14   5.98e-14     -0.957      0.339   -1.75e-13    6.03e-14
# block_G    -5.951e-14   6.03e-14     -0.986      0.325   -1.78e-13    5.91e-14
# ==============================================================================
# Omnibus:                       11.258   Durbin-Watson:                   0.747
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.118
# Skew:                          -0.228   Prob(JB):                     0.000316
# Kurtosis:                       3.886   Cond. No.                     3.88e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.4e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## 5. Select Significant Variables

# %%
significant_vars = model.pvalues[model.pvalues <= 0.5].index.tolist()
significant_vars = [v for v in significant_vars if v != "const"]

print(significant_vars)
# Out:
# ['initial', 'final', 'apartment', 'block_A', 'block_B', 'block_C', 'block_D', 'block_E', 'block_F', 'block_G']

# %% [markdown]
# ## 6. Individual Regressions

# %%
df_sig = df[significant_vars + ["consumption"]]

results = []
for col in significant_vars:
    x = sm.add_constant(df_sig[[col]].astype(float))
    y = df_sig["consumption"].astype(float)
    model = sm.OLS(y, x).fit()
    results.append({
        "Variable": col,
        "P-value": model.pvalues[col],
        "R² (individual)": model.rsquared
    })

summary_table = pd.DataFrame(results).sort_values(by="R² (individual)", ascending=False)
print(summary_table)
# Out:
#     Variable       P-value  R² (individual)
# 1      final  2.578461e-24         0.234433
# 0    initial  1.693518e-23         0.227032
# 3    block_A  5.549339e-04         0.030296
# 4    block_B  6.160288e-02         0.008975
# 7    block_E  6.175288e-02         0.008965
# 6    block_D  8.460062e-02         0.007646
# 8    block_F  1.765181e-01         0.004703
# 9    block_G  4.038639e-01         0.001797
# 2  apartment  5.054138e-01         0.001144
# 5    block_C  6.058566e-01         0.000687

# %% [markdown]
# ## 7. Simple Linear Regression

# %%
for var in summary_table["Variable"]:
  print("Variable chosen: " + var )
  x = df[[var]]
  y = df["consumption"]

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=21)

  results_poly = []

  for degree in range(1, 8):
      poly_f = PolynomialFeatures(degree=degree)
      x_train_poly = poly_f.fit_transform(x_train)
      x_test_poly = poly_f.transform(x_test)

      lin_reg = LinearRegression()
      lin_reg.fit(x_train_poly, y_train)

      r2_train = lin_reg.score(x_train_poly, y_train)
      r2_test = lin_reg.score(x_test_poly, y_test)
      diff = abs(r2_train - r2_test)

      results_poly.append((degree, r2_train, r2_test, diff))
      print(f"Degree: {degree} — R² Train: {r2_train:.4f}, R² Test: {r2_test:.4f}, Diff: {diff:.4f}")

  results_df = pd.DataFrame(results_poly, columns=["Degree", "R2_Train", "R2_Test", "Difference"])
  print("\nBest degree (smallest train-test R² difference):")
  print(results_df.loc[results_df["Difference"].idxmin()])
  print("\n-----------------------------------------------------------\n")
# Out:
# Variable chosen: final
# Degree: 1 — R² Train: 0.2588, R² Test: 0.1580, Diff: 0.1008
# Degree: 2 — R² Train: 0.2708, R² Test: 0.1250, Diff: 0.1458
# Degree: 3 — R² Train: 0.2796, R² Test: 0.1676, Diff: 0.1120
# Degree: 4 — R² Train: 0.2807, R² Test: 0.1327, Diff: 0.1480
# Degree: 5 — R² Train: 0.2802, R² Test: -0.0206, Diff: 0.3008
# Degree: 6 — R² Train: 0.2799, R² Test: -0.3378, Diff: 0.6177
# Degree: 7 — R² Train: 0.2791, R² Test: -2.0334, Diff: 2.3126
#
# Best degree (smallest train-test R² difference):
# Degree        1.000000
# R2_Train      0.258764
# R2_Test       0.157978
# Difference    0.100786
# Name: 0, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: initial
# Degree: 1 — R² Train: 0.2509, R² Test: 0.1518, Diff: 0.0991
# Degree: 2 — R² Train: 0.2631, R² Test: 0.1197, Diff: 0.1434
# Degree: 3 — R² Train: 0.2720, R² Test: 0.1622, Diff: 0.1097
# Degree: 4 — R² Train: 0.2733, R² Test: 0.1209, Diff: 0.1524
# Degree: 5 — R² Train: 0.2722, R² Test: -0.0311, Diff: 0.3033
# Degree: 6 — R² Train: 0.2720, R² Test: -0.3588, Diff: 0.6308
# Degree: 7 — R² Train: 0.2712, R² Test: -2.1673, Diff: 2.4384
#
# Best degree (smallest train-test R² difference):
# Degree        1.000000
# R2_Train      0.250886
# R2_Test       0.151818
# Difference    0.099068
# Name: 0, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: block_A
# Degree: 1 — R² Train: 0.0376, R² Test: -0.0014, Diff: 0.0390
# Degree: 2 — R² Train: 0.0376, R² Test: -0.0014, Diff: 0.0390
# Degree: 3 — R² Train: 0.0376, R² Test: -0.0014, Diff: 0.0390
# Degree: 4 — R² Train: 0.0376, R² Test: -0.0014, Diff: 0.0390
# Degree: 5 — R² Train: 0.0376, R² Test: -0.0014, Diff: 0.0390
# Degree: 6 — R² Train: 0.0376, R² Test: -0.0014, Diff: 0.0390
# Degree: 7 — R² Train: 0.0376, R² Test: -0.0014, Diff: 0.0390
#
# Best degree (smallest train-test R² difference):
# Degree        1.000000
# R2_Train      0.037590
# R2_Test      -0.001372
# Difference    0.038961
# Name: 0, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: block_B
# Degree: 1 — R² Train: 0.0030, R² Test: 0.0115, Diff: 0.0085
# Degree: 2 — R² Train: 0.0030, R² Test: 0.0115, Diff: 0.0085
# Degree: 3 — R² Train: 0.0030, R² Test: 0.0115, Diff: 0.0085
# Degree: 4 — R² Train: 0.0030, R² Test: 0.0115, Diff: 0.0085
# Degree: 5 — R² Train: 0.0030, R² Test: 0.0115, Diff: 0.0085
# Degree: 6 — R² Train: 0.0030, R² Test: 0.0115, Diff: 0.0085
# Degree: 7 — R² Train: 0.0030, R² Test: 0.0115, Diff: 0.0085
#
# Best degree (smallest train-test R² difference):
# Degree        1.000000
# R2_Train      0.003025
# R2_Test       0.011535
# Difference    0.008510
# Name: 0, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: block_E
# Degree: 1 — R² Train: 0.0223, R² Test: -0.0457, Diff: 0.0680
# Degree: 2 — R² Train: 0.0223, R² Test: -0.0457, Diff: 0.0680
# Degree: 3 — R² Train: 0.0223, R² Test: -0.0457, Diff: 0.0680
# Degree: 4 — R² Train: 0.0223, R² Test: -0.0457, Diff: 0.0680
# Degree: 5 — R² Train: 0.0223, R² Test: -0.0457, Diff: 0.0680
# Degree: 6 — R² Train: 0.0223, R² Test: -0.0457, Diff: 0.0680
# Degree: 7 — R² Train: 0.0223, R² Test: -0.0457, Diff: 0.0680
#
# Best degree (smallest train-test R² difference):
# Degree        6.000000
# R2_Train      0.022328
# R2_Test      -0.045687
# Difference    0.068015
# Name: 5, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: block_D
# Degree: 1 — R² Train: 0.0104, R² Test: -0.0084, Diff: 0.0188
# Degree: 2 — R² Train: 0.0104, R² Test: -0.0084, Diff: 0.0188
# Degree: 3 — R² Train: 0.0104, R² Test: -0.0084, Diff: 0.0188
# Degree: 4 — R² Train: 0.0104, R² Test: -0.0084, Diff: 0.0188
# Degree: 5 — R² Train: 0.0104, R² Test: -0.0084, Diff: 0.0188
# Degree: 6 — R² Train: 0.0104, R² Test: -0.0084, Diff: 0.0188
# Degree: 7 — R² Train: 0.0104, R² Test: -0.0084, Diff: 0.0188
#
# Best degree (smallest train-test R² difference):
# Degree        3.000000
# R2_Train      0.010370
# R2_Test      -0.008445
# Difference    0.018816
# Name: 2, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: block_F
# Degree: 1 — R² Train: 0.0034, R² Test: -0.0006, Diff: 0.0040
# Degree: 2 — R² Train: 0.0034, R² Test: -0.0006, Diff: 0.0040
# Degree: 3 — R² Train: 0.0034, R² Test: -0.0006, Diff: 0.0040
# Degree: 4 — R² Train: 0.0034, R² Test: -0.0006, Diff: 0.0040
# Degree: 5 — R² Train: 0.0034, R² Test: -0.0006, Diff: 0.0040
# Degree: 6 — R² Train: 0.0034, R² Test: -0.0006, Diff: 0.0040
# Degree: 7 — R² Train: 0.0034, R² Test: -0.0006, Diff: 0.0040
#
# Best degree (smallest train-test R² difference):
# Degree        3.000000
# R2_Train      0.003360
# R2_Test      -0.000612
# Difference    0.003972
# Name: 2, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: block_G
# Degree: 1 — R² Train: 0.0021, R² Test: -0.0076, Diff: 0.0097
# Degree: 2 — R² Train: 0.0021, R² Test: -0.0076, Diff: 0.0097
# Degree: 3 — R² Train: 0.0021, R² Test: -0.0076, Diff: 0.0097
# Degree: 4 — R² Train: 0.0021, R² Test: -0.0076, Diff: 0.0097
# Degree: 5 — R² Train: 0.0021, R² Test: -0.0076, Diff: 0.0097
# Degree: 6 — R² Train: 0.0021, R² Test: -0.0076, Diff: 0.0097
# Degree: 7 — R² Train: 0.0021, R² Test: -0.0076, Diff: 0.0097
#
# Best degree (smallest train-test R² difference):
# Degree        2.000000
# R2_Train      0.002075
# R2_Test      -0.007576
# Difference    0.009651
# Name: 1, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: apartment
# Degree: 1 — R² Train: 0.0035, R² Test: -0.0171, Diff: 0.0206
# Degree: 2 — R² Train: 0.0066, R² Test: -0.0336, Diff: 0.0402
# Degree: 3 — R² Train: 0.0080, R² Test: -0.0379, Diff: 0.0460
# Degree: 4 — R² Train: 0.0124, R² Test: -0.0479, Diff: 0.0602
# Degree: 5 — R² Train: 0.0131, R² Test: -0.0630, Diff: 0.0761
# Degree: 6 — R² Train: 0.0127, R² Test: -0.0686, Diff: 0.0813
# Degree: 7 — R² Train: 0.0121, R² Test: -0.0593, Diff: 0.0714
#
# Best degree (smallest train-test R² difference):
# Degree        1.000000
# R2_Train      0.003518
# R2_Test      -0.017100
# Difference    0.020618
# Name: 0, dtype: float64
#
# -----------------------------------------------------------
#
# Variable chosen: block_C
# Degree: 1 — R² Train: 0.0048, R² Test: -0.0245, Diff: 0.0293
# Degree: 2 — R² Train: 0.0048, R² Test: -0.0245, Diff: 0.0293
# Degree: 3 — R² Train: 0.0048, R² Test: -0.0245, Diff: 0.0293
# Degree: 4 — R² Train: 0.0048, R² Test: -0.0245, Diff: 0.0293
# Degree: 5 — R² Train: 0.0048, R² Test: -0.0245, Diff: 0.0293
# Degree: 6 — R² Train: 0.0048, R² Test: -0.0245, Diff: 0.0293
# Degree: 7 — R² Train: 0.0048, R² Test: -0.0245, Diff: 0.0293
#
# Best degree (smallest train-test R² difference):
# Degree        3.000000
# R2_Train      0.004792
# R2_Test      -0.024526
# Difference    0.029317
# Name: 2, dtype: float64
#
# -----------------------------------------------------------
