# %%
from scipy.stats import norm, binom

mu = 5
sigma = 0.2

prob_normal = 1 - norm.cdf(5.3, mu, sigma)
print(f"{prob_normal:.3f}")
# Out:
# 0.067

# %%
mu = 120
sigma = 15

prob_normal = norm.cdf(100, mu, sigma)
print(f"Chance of finishing the exam in 100 minutes: {prob_normal:.3f}")

prob_normal = 1 - norm.cdf(150, mu, sigma)
print(f"Chance of finishing the exam in more than 150 minutes: {prob_normal:.3f}")

prob_normal1 = norm.cdf(110, mu, sigma)
prob_normal2 = norm.cdf(140, mu, sigma)
print(f"Chance of finishing the exam between 110 and 140 minutes: {(prob_normal2 - prob_normal1):.3f}")

percentage = norm.ppf(0.95, mu, sigma)
print(f"Minimum duration so that 95% of all students finish: {percentage:.3f}")

percentage = norm.ppf(0.2, mu, sigma)
print(f"Maximum duration so that 20% of the fastest students finish: {percentage:.3f}")
# Out:
# Chance of finishing the exam in 100 minutes: 0.091
# Chance of finishing the exam in more than 150 minutes: 0.023
# Chance of finishing the exam between 110 and 140 minutes: 0.656
# Minimum duration so that 95% of all students finish: 144.673
# Maximum duration so that 20% of the fastest students finish: 107.376

# %%
n = 10
p = 0.1

prob_binomial = binom.pmf(2, n, p)
print(f"Probability of exactly 2 successes out of 10 trials: {prob_binomial:.3f}")

sumAll = 0
for i in range(2, 11):
    prob_binomial = binom.pmf(i, n, p)
    sumAll += prob_binomial
print(f"Probability of getting 2 or more successes out of 10 trials: {sumAll:.3f}")

n = 100
prob_binomial = binom.pmf(20, n, p)
print(f"Probability of exactly 20 successes out of 100 trials: {prob_binomial:.3f}")
# Out:
# Probability of exactly 2 successes out of 10 trials: 0.194
# Probability of getting 2 or more successes out of 10 trials: 0.264
# Probability of exactly 20 successes out of 100 trials: 0.001
