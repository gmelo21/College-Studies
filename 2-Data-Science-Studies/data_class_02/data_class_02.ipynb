# %%
import pandas as pd

# Setting the list dataframe as our main one:
df = pd.read_csv('/content/data_list.csv')

# Printing the whole list dataframe:
df
# Out:
#            Base de Dados                                          Exercício
# 0   Heróis (Marvel & DC)       1️⃣ Liste todos os heróis da editora Marvel.
# 1   Heróis (Marvel & DC)           2️⃣ Qual é o herói mais antigo da lista?
# 2   Heróis (Marvel & DC)      3️⃣ Qual é a média de força dos heróis da DC?
# 3   Heróis (Marvel & DC)  4️⃣ Qual editora tem a maior média de inteligê...
# 4   Heróis (Marvel & DC)                     5️⃣ Qual é o herói mais veloz?
# 5   Heróis (Marvel & DC)        6️⃣ Quantos heróis estrearam antes de 1960?
# 6   Heróis (Marvel & DC)  7️⃣ Qual é a soma total da força dos heróis da...
# 7   Heróis (Marvel & DC)  8️⃣ Liste os heróis em ordem decrescente de ve...
# 8   Heróis (Marvel & DC)    9️⃣ Qual é a média de estreia dos heróis da DC?
# 9   Heróis (Marvel & DC)     🔟 Qual o nome do herói mais forte entre todos?
# 10           Corinthians              1️⃣ Qual foi o ano com mais vitórias?
# ...

# %%
# 1-10 - Setting the heroes dataframe as our main one:
df = pd.read_csv('/content/data_heroes.csv')

# Printing the whole heroes dataframe:
df
# Out:
#                Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 0            Batman      DC         1939     85           100          80
# 1          Superman      DC         1938    100            90         100
# 2  Mulher-Maravilha      DC         1941     95            92          85
# 3    Homem de Ferro  Marvel         1963     90           100          88
# 4   Capitão América  Marvel         1941     92            85          84
# 5              Hulk  Marvel         1962    100            80          75
# 6             Flash      DC         1956     88            88         100
# 7              Thor  Marvel         1962    100            90          90
# 8           Aquaman      DC         1941     86            82          85
# 9      Homem-Aranha  Marvel         1962     89            85          95

# %%
# 1 - List all the heroes from Marvel Comics.

df[df['Editora'] == 'Marvel']
# Out:
#               Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 3   Homem de Ferro  Marvel         1963     90           100          88
# 4  Capitão América  Marvel         1941     92            85          84
# 5             Hulk  Marvel         1962    100            80          75
# 7             Thor  Marvel         1962    100            90          90
# 9     Homem-Aranha  Marvel         1962     89            85          95

# %%
# 2 - Who is the oldest hero on the list?

df.loc[df['Ano_Estreia'] == df['Ano_Estreia'].min()][['Nome', 'Ano_Estreia']]
# Out:
#        Nome  Ano_Estreia
# 1  Superman         1938

# %%
# 3 - What is the average strength of the DC heroes?

df[df['Editora'] == 'DC']['Força'].mean()
# Out:
# 90.8

# %%
# 4 - Which publisher has the highest average intelligence?

df.groupby('Editora')['Inteligência'].mean().sort_values(ascending=False)
# Out:
# Editora
# DC        90.4
# Marvel    88.0
# Name: Inteligência, dtype: float64

# %%
# 5 - Who is the fastest hero?

df.loc[df['Velocidade'] == df['Velocidade'].max()][['Nome', 'Velocidade']]
# Out:
#        Nome  Velocidade
# 1  Superman         100
# 6     Flash         100

# %%
# 6 - How many heroes debuted before 1960?

len(df[df['Ano_Estreia'] < 1960])
# Out:
# 6

# %%
# 7 - What is the total strength of the DC heroes?

df[df['Editora'] == 'DC']['Força'].sum()
# Out:
# 454

# %%
# 8 - List the heroes in descending order of speed.

df.sort_values('Velocidade', ascending=False)[['Nome', 'Velocidade']]
# Out:
#                Nome  Velocidade
# 1          Superman         100
# 6             Flash         100
# 9      Homem-Aranha          95
# 7              Thor          90
# 3    Homem de Ferro          88
# 2  Mulher-Maravilha          85
# 8           Aquaman          85
# 4   Capitão América          84
# 0            Batman          80
# 5              Hulk          75

# %%
# 9 - What is the average debut year of the DC heroes?

df[df['Editora'] == 'DC']['Ano_Estreia'].mean()
# Out:
# 1943.0

# %%
# 10 - What is the name of the strongest hero among all?

df.loc[df['Força'] == df['Força'].max()][['Nome', 'Força']]
# Out:
#        Nome  Força
# 1  Superman    100
# 5      Hulk    100
# 7      Thor    100

# %%
# 11-20 - Setting the team dataframe as our main one:
df = pd.read_csv('/content/data_team.csv')

# Printing the whole team dataframe:
df
# Out:
#     Ano  Jogos  Vitórias  Empates  Derrotas  Gols_Marcados  Gols_Sofridos  \
# 0  2015     61        30       14        12             49             59
# 1  2016     42        27       10        11             85             29
# 2  2017     69        35        6         6             58             41
# 3  2018     47        27       11        14             30             29
# 4  2019     56        33       11        11             49             29
# 5  2020     45        32        8         6             72             49
# 6  2021     49        35       12         8             70             20
# 7  2022     40        36        7        10             70             34
# 8  2023     53        30       13        14             37             48
# 9  2024     64        22        6         5             89             48
#
#    Posição_Campeonato
# 0                  19
# 1                   4
# 2                  10
# 3                  17
# 4                   6
# ...

# %%
# 11 - What year had the most victories?

df[df['Vitórias'] == df['Vitórias'].max()][['Ano', 'Vitórias']]
# Out:
#     Ano  Vitórias
# 7  2022        36

# %%
# 12 - What was the goal difference (goals scored - goals conceded) in each year?

df[['Ano']].assign(Diferença_Gols = df['Gols_Marcados'] - df['Gols_Sofridos'])
# Out:
#     Ano  Diferença_Gols
# 0  2015             -10
# 1  2016              56
# 2  2017              17
# 3  2018               1
# 4  2019              20
# 5  2020              23
# 6  2021              50
# 7  2022              36
# 8  2023             -11
# 9  2024              41

# %%
# 13 - What is the average final position of Corinthians in the championships?

df['Posição_Campeonato'].mean()
# Out:
# 12.3

# %%
# 14 - Which year had the fewest losses?

df[df['Derrotas'] == df['Derrotas'].min()][['Ano', 'Derrotas']]
# Out:
#     Ano  Derrotas
# 9  2024         5

# %%
# 15 - In which years did Corinthians score more than 60 goals?

df[df['Gols_Marcados'] > 60][['Ano', 'Gols_Marcados']]
# Out:
#     Ano  Gols_Marcados
# 1  2016             85
# 5  2020             72
# 6  2021             70
# 7  2022             70
# 9  2024             89

# %%
# 16 - What was the win rate (%) per year?

df[['Ano']].assign(Taxa_Vitórias = ((df['Vitórias'] / df['Jogos']) * 100).round(2))
# Out:
#     Ano  Taxa_Vitórias
# 0  2015          49.18
# 1  2016          64.29
# 2  2017          50.72
# 3  2018          57.45
# 4  2019          58.93
# 5  2020          71.11
# 6  2021          71.43
# 7  2022          90.00
# 8  2023          56.60
# 9  2024          34.38

# %%
# 17 - List the years in descending order of points (Wins = 3 points, Draws = 1 point).

df[['Ano']].assign(Pontos = (df['Vitórias'] * 3) + (df['Empates'] * 1)).sort_values(by='Pontos', ascending=False)
# Out:
#     Ano  Pontos
# 6  2021     117
# 7  2022     115
# 2  2017     111
# 4  2019     110
# 0  2015     104
# 5  2020     104
# 8  2023     103
# 3  2018      92
# 1  2016      91
# 9  2024      72

# %%
# 18 - What was the worst position of Corinthians in this period?

df[df['Posição_Campeonato'] == df['Posição_Campeonato'].max()][['Ano', 'Posição_Campeonato']]
# Out:
#     Ano  Posição_Campeonato
# 0  2015                  19
# 9  2024                  19

# %%
# 19 - What year had the most games played?

df[df['Jogos'] == df['Jogos'].max()][['Ano', 'Jogos']]
# Out:
#     Ano  Jogos
# 2  2017     69

# %%
# 20 - What is the average goals taken per game in each year?

df[['Ano']].assign(Média_Gols_Sofridos = df['Gols_Sofridos'] / df['Jogos']).round(2)
# Out:
#     Ano  Média_Gols_Sofridos
# 0  2015                 0.97
# 1  2016                 0.69
# 2  2017                 0.59
# 3  2018                 0.62
# 4  2019                 0.52
# 5  2020                 1.09
# 6  2021                 0.41
# 7  2022                 0.85
# 8  2023                 0.91
# 9  2024                 0.75

# %%
# 21-30 - Setting the movies dataframe as our main one:
df = pd.read_csv('/content/data_movies.csv')

# Printing the whole movies dataframe:
df
# Out:
#                  Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 0     O Poderoso Chefão  1972                 287        9.2              175
# 1               Titanic  1997                2187        7.8              195
# 2          Interestelar  2014                 701        8.6              169
# 3                Matrix  1999                 466        8.7              136
# 4  Vingadores: Ultimato  2019                2798        8.4              181
# 5         Clube da Luta  1999                 101        8.8              139
# 6          Pulp Fiction  1994                 213        8.9              154
# 7    O Senhor dos Anéis  2001                2917        8.8              178
# 8               Coringa  2019                1074        8.4              122
# 9                  Duna  2021                 402        8.0              155
#
#               Gênero
# 0              Crime
# 1            Romance
# 2  Ficção Científica
# 3  Ficção Científica
# ...

# %%
# 21 - List the movies in the 'Science Fiction' genre.

df[df['Gênero'] == 'Ficção Científica']
# Out:
#          Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 2  Interestelar  2014                 701        8.6              169
# 3        Matrix  1999                 466        8.7              136
# 9          Duna  2021                 402        8.0              155
#
#               Gênero
# 2  Ficção Científica
# 3  Ficção Científica
# 9  Ficção Científica

# %%
# 22 - What is the oldest movie on the list?

df[df['Ano'] == df['Ano'].min()][['Título', 'Ano']]
# Out:
#               Título   Ano
# 0  O Poderoso Chefão  1972

# %%
# 23 - What is the average box office of the movies on the list?

df['Bilheteria_Mundial'].mean()
# Out:
# 1114.6

# %%
# 24 - Which movie had the highest rating on IMDb?

df[df['Nota_IMDb'] == df['Nota_IMDb'].max()][['Título', 'Nota_IMDb']]
# Out:
#               Título  Nota_IMDb
# 0  O Poderoso Chefão        9.2

# %%
# 25 - List the movies in descending order of duration.

df.sort_values('Duração_Minutos', ascending=False)[['Título', 'Duração_Minutos']]
# Out:
#                  Título  Duração_Minutos
# 1               Titanic              195
# 4  Vingadores: Ultimato              181
# 7    O Senhor dos Anéis              178
# 0     O Poderoso Chefão              175
# 2          Interestelar              169
# 9                  Duna              155
# 6          Pulp Fiction              154
# 5         Clube da Luta              139
# 3                Matrix              136
# 8               Coringa              122

# %%
# 26 - What is the total worldwide box office of all the movies?

df['Bilheteria_Mundial'].sum()
# Out:
# 11146

# %%
# 27 - Which movie had a duration of less than 150 minutes?

df[df['Duração_Minutos'] < 150][['Título', 'Duração_Minutos']]
# Out:
#           Título  Duração_Minutos
# 3         Matrix              136
# 5  Clube da Luta              139
# 8        Coringa              122

# %%
# 28 - List the movies released after the year 2000.

df[df['Ano'] > 2000][['Título', 'Ano']]
# Out:
#                  Título   Ano
# 2          Interestelar  2014
# 4  Vingadores: Ultimato  2019
# 7    O Senhor dos Anéis  2001
# 8               Coringa  2019
# 9                  Duna  2021

# %%
# 29 - What is the average duration of the movies on the list?

df['Duração_Minutos'].mean()
# Out:
# 160.4

# %%
# 30 - Which movie has the highest worldwide box office?

df[df['Bilheteria_Mundial'] == df['Bilheteria_Mundial'].max()][['Título', 'Bilheteria_Mundial']]
# Out:
#                Título  Bilheteria_Mundial
# 7  O Senhor dos Anéis                2917
